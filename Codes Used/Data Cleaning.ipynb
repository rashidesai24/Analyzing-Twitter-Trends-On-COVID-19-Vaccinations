# %%
import pandas as pd
import string
import sys,csv,re

# %%
Tweets_Jan = pd.read_csv('Tweets_March.csv')
# Out:
# C:\Users\shahh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
Tweets_Jan.head(5)
# Out:
#                     Datetime             Tweet Id  \
# 0  2021-03-05 23:59:59+00:00  1367990000000000000
# 1  2021-03-05 23:59:58+00:00  1367990000000000000
# 2  2021-03-05 23:59:58+00:00  1367990000000000000
# 3  2021-03-05 23:59:58+00:00  1367990000000000000
# 4  2021-03-05 23:59:51+00:00  1367990000000000000
#
#                                                 Text        Username  \
# 0  A fourth #COVIDvaccine is now approved (below)...  stephen_scally
# 1  Anyone know how I compete in the hunger games ...     emilyholley
# 2  Getting the second dose of my covid vaccine in...      JeSuisAsha
# 3  First #Moderna shot down! #CovidVaccine #LetsG...          dphilz
# 4  *****MANY ARE TAKING THE COVID-19 VACCINE****M...   The_News_UNIT
#
#   Like Count                                Display Name Language
# 0          2                                Life Lessons       en
# 1          0     Emily *Still* Wear the Damn Mask Holley       en
# 2         18                                  Dr A S H A       en
# 3          5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4          0                                   News UNIT       en

# %%
Tweets_Jan = Tweets_Jan.rename(columns={'Tweet ID': 'Tweet Id'})

# %%
Tweets_Jan.head(5)
# Out:
#                     Datetime             Tweet Id  \
# 0  2021-03-05 23:59:59+00:00  1367990000000000000
# 1  2021-03-05 23:59:58+00:00  1367990000000000000
# 2  2021-03-05 23:59:58+00:00  1367990000000000000
# 3  2021-03-05 23:59:58+00:00  1367990000000000000
# 4  2021-03-05 23:59:51+00:00  1367990000000000000
#
#                                                 Text        Username  \
# 0  A fourth #COVIDvaccine is now approved (below)...  stephen_scally
# 1  Anyone know how I compete in the hunger games ...     emilyholley
# 2  Getting the second dose of my covid vaccine in...      JeSuisAsha
# 3  First #Moderna shot down! #CovidVaccine #LetsG...          dphilz
# 4  *****MANY ARE TAKING THE COVID-19 VACCINE****M...   The_News_UNIT
#
#   Like Count                                Display Name Language
# 0          2                                Life Lessons       en
# 1          0     Emily *Still* Wear the Damn Mask Holley       en
# 2         18                                  Dr A S H A       en
# 3          5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4          0                                   News UNIT       en

# %%
Tweets_Jan.shape
# Out:
# (1127854, 7)

# %%
Tweets_J = Tweets_Jan[Tweets_Jan['Language']=='en']

# %%
Tweets_J.shape
# Out:
# (1082567, 7)

# %%
Tweets_J.reset_index(drop=True)
# Out:
#                           Datetime             Tweet Id  \
# 0        2021-03-05 23:59:59+00:00  1367990000000000000
# 1        2021-03-05 23:59:58+00:00  1367990000000000000
# 2        2021-03-05 23:59:58+00:00  1367990000000000000
# 3        2021-03-05 23:59:58+00:00  1367990000000000000
# 4        2021-03-05 23:59:51+00:00  1367990000000000000
# ...                            ...                  ...
# 1082562  2021-03-06 00:00:00+00:00  1367990000000000000
# 1082563  2021-03-06 00:00:00+00:00  1367990000000000000
# 1082564  2021-03-06 00:00:00+00:00  1367990000000000000
# 1082565  2021-03-06 00:00:00+00:00  1367990000000000000
# 1082566  2021-03-06 00:00:00+00:00  1367990000000000000
#
#                                                       Text        Username  \
# 0        A fourth #COVIDvaccine is now approved (below)...  stephen_scally
# 1        Anyone know how I compete in the hunger games ...     emilyholley
# 2        Getting the second dose of my covid vaccine in...      JeSuisAsha
# 3        First #Moderna shot down! #CovidVaccine #LetsG...          dphilz
# 4        *****MANY ARE TAKING THE COVID-19 VACCINE****M...   The_News_UNIT
# ...                                                    ...             ...
# 1082562  Language barriers have made it difficult for m...    usatodaytech
# 1082563  Apes in San Diego got the COVID vaccine! \n\nh...      TheMarySue
# 1082564  All nine Supreme Court justices have now recei...    WISCTV_News3
# 1082565  Language barriers have made it difficult for m...   USATODAYmoney
# 1082566  Homerton Hospital will start administering the...  HealthwatchCoL
#
#         Like Count                                Display Name Language
# 0                2                                Life Lessons       en
# 1                0     Emily *Still* Wear the Damn Mask Holley       en
# 2               18                                  Dr A S H A       en
# 3                5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4                0                                   News UNIT       en
# ...            ...                                         ...      ...
# 1082562          1                              USA TODAY Tech       en
# 1082563         14                                The Mary Sue       en
# 1082564          0                   News 3 Now / Channel 3000       en
# 1082565          0                             USA TODAY Money       en
# 1082566          0                             Healthwatch CoL       en
#
# [1082567 rows x 7 columns]

# %%
#All LowerCase
Tweets_J['Text'] = Tweets_J['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
Tweets_J.head()
# Out:
# <ipython-input-10-9f877e32bbee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_J['Text'] = Tweets_J['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
#                     Datetime             Tweet Id  \
# 0  2021-03-05 23:59:59+00:00  1367990000000000000
# 1  2021-03-05 23:59:58+00:00  1367990000000000000
# 2  2021-03-05 23:59:58+00:00  1367990000000000000
# 3  2021-03-05 23:59:58+00:00  1367990000000000000
# 4  2021-03-05 23:59:51+00:00  1367990000000000000
#
#                                                 Text        Username  \
# 0  a fourth #covidvaccine is now approved (below)...  stephen_scally
# 1  anyone know how i compete in the hunger games ...     emilyholley
# 2  getting the second dose of my covid vaccine in...      JeSuisAsha
# 3  first #moderna shot down! #covidvaccine #letsg...          dphilz
# 4  *****many are taking the covid-19 vaccine****m...   The_News_UNIT
#
#   Like Count                                Display Name Language
# 0          2                                Life Lessons       en
# 1          0     Emily *Still* Wear the Damn Mask Holley       en
# 2         18                                  Dr A S H A       en
# 3          5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4          0                                   News UNIT       en

# %%
#Removing Punctuation
Tweets_J['Text_punc'] = Tweets_J['Text'].str.replace('[^\w\s]','')
Tweets_J.head()
# Out:
# <ipython-input-11-da658bd66476>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_J['Text_punc'] = Tweets_J['Text'].str.replace('[^\w\s]','')
#                     Datetime             Tweet Id  \
# 0  2021-03-05 23:59:59+00:00  1367990000000000000
# 1  2021-03-05 23:59:58+00:00  1367990000000000000
# 2  2021-03-05 23:59:58+00:00  1367990000000000000
# 3  2021-03-05 23:59:58+00:00  1367990000000000000
# 4  2021-03-05 23:59:51+00:00  1367990000000000000
#
#                                                 Text        Username  \
# 0  a fourth #covidvaccine is now approved (below)...  stephen_scally
# 1  anyone know how i compete in the hunger games ...     emilyholley
# 2  getting the second dose of my covid vaccine in...      JeSuisAsha
# 3  first #moderna shot down! #covidvaccine #letsg...          dphilz
# 4  *****many are taking the covid-19 vaccine****m...   The_News_UNIT
#
#   Like Count                                Display Name Language  \
# 0          2                                Life Lessons       en
# 1          0     Emily *Still* Wear the Damn Mask Holley       en
# 2         18                                  Dr A S H A       en
# 3          5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4          0                                   News UNIT       en
#
#                                            Text_punc
# 0  a fourth covidvaccine is now approved below by...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first moderna shot down covidvaccine letsgo le...
# 4  many are taking the covid19 vaccinemany there ...

# %%
#Removal of stop words
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
#stop.append("covid vaccine")
#stop.append("covid19 vaccine")
Tweets_J['Text_stop']  = Tweets_J['Text_punc'] .apply(lambda x: " ".join(x for x in x.split() if x not in stop))
Tweets_J.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shahh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-12-53aa9a09d67a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_J['Text_stop']  = Tweets_J['Text_punc'] .apply(lambda x: " ".join(x for x in x.split() if x not in stop))
#                     Datetime             Tweet Id  \
# 0  2021-03-05 23:59:59+00:00  1367990000000000000
# 1  2021-03-05 23:59:58+00:00  1367990000000000000
# 2  2021-03-05 23:59:58+00:00  1367990000000000000
# 3  2021-03-05 23:59:58+00:00  1367990000000000000
# 4  2021-03-05 23:59:51+00:00  1367990000000000000
#
#                                                 Text        Username  \
# 0  a fourth #covidvaccine is now approved (below)...  stephen_scally
# 1  anyone know how i compete in the hunger games ...     emilyholley
# 2  getting the second dose of my covid vaccine in...      JeSuisAsha
# 3  first #moderna shot down! #covidvaccine #letsg...          dphilz
# 4  *****many are taking the covid-19 vaccine****m...   The_News_UNIT
#
#   Like Count                                Display Name Language  \
# 0          2                                Life Lessons       en
# 1          0     Emily *Still* Wear the Damn Mask Holley       en
# 2         18                                  Dr A S H A       en
# 3          5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´       en
# 4          0                                   News UNIT       en
#
#                                            Text_punc  \
# 0  a fourth covidvaccine is now approved below by...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first moderna shot down covidvaccine letsgo le...
# 4  many are taking the covid19 vaccinemany there ...
#
#                                            Text_stop
# 0  fourth covidvaccine approved time biden took o...
# 1  anyone know compete hunger games vaccine iowa ...
# 2  getting second dose covid vaccine 2 weeks alha...
# 3  first moderna shot covidvaccine letsgo levelup...
# 4  many taking covid19 vaccinemany go thereat htt...

# %%
#Tokenization of Tweets
import textblob           
from textblob import TextBlob
def tokenization(text):
    text = re.split('\W+', text)
    return text
Tweets_J['Text_tokenized'] = Tweets_J['Text_stop'].apply(lambda x: tokenization(x.lower()))
Tweets_J[['Text', 'Text_punc', 'Text_stop', 'Text_tokenized']][0:9]
# Out:
# <ipython-input-13-1c9a5cdfe690>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_J['Text_tokenized'] = Tweets_J['Text_stop'].apply(lambda x: tokenization(x.lower()))
#                                                 Text  \
# 0  a fourth #covidvaccine is now approved (below)...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first #moderna shot down! #covidvaccine #letsg...
# 4  *****many are taking the covid-19 vaccine****m...
# 5  @scottishsun @boblister_poole now things are t...
# 6  i believe that one of the side effects of the ...
# 7  but can't you still transmit the virus even if...
# 9  üî•üí•‚äºô∏èdon: did you see this piece ‚å¶@...
#
#                                            Text_punc  \
# 0  a fourth covidvaccine is now approved below by...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first moderna shot down covidvaccine letsgo le...
# 4  many are taking the covid19 vaccinemany there ...
# 5  scottishsun boblister_poole now things are tak...
# 6  i believe that one of the side effects of the ...
# 7  but cant you still transmit the virus even if ...
# 9  üîüíäºôèdon did you see this piece ådonwinslow...
#
#                                            Text_stop  \
# 0  fourth covidvaccine approved time biden took o...
# 1  anyone know compete hunger games vaccine iowa ...
# 2  getting second dose covid vaccine 2 weeks alha...
# 3  first moderna shot covidvaccine letsgo levelup...
# 4  many taking covid19 vaccinemany go thereat htt...
# 5  scottishsun boblister_poole things taking scot...
# 6  believe one side effects covid19 vaccine burni...
# 7  cant still transmit virus even youve vaccinate...
# 9  üîüíäºôèdon see piece ådonwinslowå åâôè abbott...
#
#                                       Text_tokenized
# 0  [fourth, covidvaccine, approved, time, biden, ...
# 1  [anyone, know, compete, hunger, games, vaccine...
# 2  [getting, second, dose, covid, vaccine, 2, wee...
# 3  [first, moderna, shot, covidvaccine, letsgo, l...
# 4  [many, taking, covid19, vaccinemany, go, there...
# 5  [scottishsun, boblister_poole, things, taking,...
# 6  [believe, one, side, effects, covid19, vaccine...
# 7  [cant, still, transmit, virus, even, youve, va...
# 9  [üîüíäºôèdon, see, piece, ådonwinslowå, åâôè, ...

# %%
#Stemming refers to the removal of suffices, like “ing”, “ly”, “s”, etc. by a simple rule-based approach. 
#For this purpose, we will use PorterStemmer from the NLTK library.
#from nltk.stem import PorterStemmer
#ps = PorterStemmer()
#def stemming(text):
#    text = [ps.stem(word) for word in text]
#    return text
#
#Tweets_J['Text_stemmed'] = Tweets_J['Text_tokenized'].apply(lambda x: stemming(x))
#Tweets_J[['Text', 'Text_punc', 'Text_tokenized','Text_stop','Text_stemmed']][0:9]

# %%
#Lemmatization is a more effective option than stemming because it converts the word into its root word, 
#rather than just stripping the suffices.
#nltk.download('wordnet')
wn = nltk.WordNetLemmatizer()
def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text

Tweets_J['Text_lemmatized'] = Tweets_J['Text_tokenized'].apply(lambda x: lemmatizer(x))
Tweets_J[['Text', 'Text_punc', 'Text_tokenized','Text_stop','Text_lemmatized']][0:9]
# Out:
# <ipython-input-14-ccbdc951fa74>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_J['Text_lemmatized'] = Tweets_J['Text_tokenized'].apply(lambda x: lemmatizer(x))
#                                                 Text  \
# 0  a fourth #covidvaccine is now approved (below)...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first #moderna shot down! #covidvaccine #letsg...
# 4  *****many are taking the covid-19 vaccine****m...
# 5  @scottishsun @boblister_poole now things are t...
# 6  i believe that one of the side effects of the ...
# 7  but can't you still transmit the virus even if...
# 9  üî•üí•‚äºô∏èdon: did you see this piece ‚å¶@...
#
#                                            Text_punc  \
# 0  a fourth covidvaccine is now approved below by...
# 1  anyone know how i compete in the hunger games ...
# 2  getting the second dose of my covid vaccine in...
# 3  first moderna shot down covidvaccine letsgo le...
# 4  many are taking the covid19 vaccinemany there ...
# 5  scottishsun boblister_poole now things are tak...
# 6  i believe that one of the side effects of the ...
# 7  but cant you still transmit the virus even if ...
# 9  üîüíäºôèdon did you see this piece ådonwinslow...
#
#                                       Text_tokenized  \
# 0  [fourth, covidvaccine, approved, time, biden, ...
# 1  [anyone, know, compete, hunger, games, vaccine...
# 2  [getting, second, dose, covid, vaccine, 2, wee...
# 3  [first, moderna, shot, covidvaccine, letsgo, l...
# 4  [many, taking, covid19, vaccinemany, go, there...
# 5  [scottishsun, boblister_poole, things, taking,...
# 6  [believe, one, side, effects, covid19, vaccine...
# 7  [cant, still, transmit, virus, even, youve, va...
# 9  [üîüíäºôèdon, see, piece, ådonwinslowå, åâôè, ...
#
#                                            Text_stop  \
# 0  fourth covidvaccine approved time biden took o...
# 1  anyone know compete hunger games vaccine iowa ...
# 2  getting second dose covid vaccine 2 weeks alha...
# 3  first moderna shot covidvaccine letsgo levelup...
# 4  many taking covid19 vaccinemany go thereat htt...
# 5  scottishsun boblister_poole things taking scot...
# 6  believe one side effects covid19 vaccine burni...
# 7  cant still transmit virus even youve vaccinate...
# 9  üîüíäºôèdon see piece ådonwinslowå åâôè abbott...
#
#                                      Text_lemmatized
# 0  [fourth, covidvaccine, approved, time, biden, ...
# 1  [anyone, know, compete, hunger, game, vaccine,...
# 2  [getting, second, dose, covid, vaccine, 2, wee...
# 3  [first, moderna, shot, covidvaccine, letsgo, l...
# 4  [many, taking, covid19, vaccinemany, go, there...
# 5  [scottishsun, boblister_poole, thing, taking, ...
# 6  [believe, one, side, effect, covid19, vaccine,...
# 7  [cant, still, transmit, virus, even, youve, va...
# 9  [üîüíäºôèdon, see, piece, ådonwinslowå, åâôè, ...

# %%
Tweets_J.drop(columns=['Text', 'Text_punc', 'Text_tokenized', 'Text_stop', 'Language'])
# Out:
#                           Datetime             Tweet Id        Username  \
# 0        2021-03-05 23:59:59+00:00  1367990000000000000  stephen_scally
# 1        2021-03-05 23:59:58+00:00  1367990000000000000     emilyholley
# 2        2021-03-05 23:59:58+00:00  1367990000000000000      JeSuisAsha
# 3        2021-03-05 23:59:58+00:00  1367990000000000000          dphilz
# 4        2021-03-05 23:59:51+00:00  1367990000000000000   The_News_UNIT
# ...                            ...                  ...             ...
# 1127849  2021-03-06 00:00:00+00:00  1367990000000000000    usatodaytech
# 1127850  2021-03-06 00:00:00+00:00  1367990000000000000      TheMarySue
# 1127851  2021-03-06 00:00:00+00:00  1367990000000000000    WISCTV_News3
# 1127852  2021-03-06 00:00:00+00:00  1367990000000000000   USATODAYmoney
# 1127853  2021-03-06 00:00:00+00:00  1367990000000000000  HealthwatchCoL
#
#         Like Count                                Display Name  \
# 0                2                                Life Lessons
# 1                0     Emily *Still* Wear the Damn Mask Holley
# 2               18                                  Dr A S H A
# 3                5  Dana Philipps, Ph.D. üß¨ üîç üë©‚Äçüè´
# 4                0                                   News UNIT
# ...            ...                                         ...
# 1127849          1                              USA TODAY Tech
# 1127850         14                                The Mary Sue
# 1127851          0                   News 3 Now / Channel 3000
# 1127852          0                             USA TODAY Money
# 1127853          0                             Healthwatch CoL
#
#                                            Text_lemmatized
# 0        [fourth, covidvaccine, approved, time, biden, ...
# 1        [anyone, know, compete, hunger, game, vaccine,...
# 2        [getting, second, dose, covid, vaccine, 2, wee...
# 3        [first, moderna, shot, covidvaccine, letsgo, l...
# 4        [many, taking, covid19, vaccinemany, go, there...
# ...                                                    ...
# 1127849  [language, barrier, made, difficult, many, non...
# 1127850  [ape, san, diego, got, covid, vaccine, httpstc...
# 1127851  [nine, supreme, court, justice, received, covi...
# 1127852  [language, barrier, made, difficult, many, non...
# 1127853  [homerton, hospital, start, administering, sec...
#
# [1082567 rows x 6 columns]

# %%
Tweets_J.head()
Tweets_J.to_csv('Tweets_Mar_Cleaned.csv')

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ' '.join(list(Tweets_J['Text_stop'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
