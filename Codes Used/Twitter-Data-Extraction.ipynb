# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-28').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df2.to_csv('First Extract.csv')

# %%
tweets_df2
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-27 23:59:59+00:00  1365813964756692993
# 1      2021-02-27 23:59:59+00:00  1365813964320501767
# 2      2021-02-27 23:59:58+00:00  1365813962739179523
# 3      2021-02-27 23:59:58+00:00  1365813959333318656
# 4      2021-02-27 23:59:57+00:00  1365813958163111938
# ...                          ...                  ...
# 99996  2021-02-25 03:43:24+00:00  1364783025460940801
# 99997  2021-02-25 03:43:24+00:00  1364783024521572352
# 99998  2021-02-25 03:43:21+00:00  1364783013716893700
# 99999  2021-02-25 03:43:11+00:00  1364782969894838279
# 100000 2021-02-25 03:43:10+00:00  1364782968774955008
#
#                                                      Text         Username  \
# 0       Are you ready to roll your sleeve up for the C...           USAGov
# 1       I've been trying to tweet about Dr Yeadon, for...        seeker375
# 2       U.S. authorizes Johnson &amp; Johnson’s COVID-...         tspindex
# 3       The Food and Drug Administration has authorize...  Richard31225984
# 4       @AP There’s three COVID-19 vaccines but Flint,...   NxtLevelPromo_
# ...                                                   ...              ...
# 99996   #COVIDVaccine \n“DEN BOSCH – There have so far...        welosthim
# 99997   https://t.co/F6dBqc0lp2\n#COVID19 #Covid_19\n#...     mindbodyslim
# 99998   In a boost for battle against COVID-19, Pfizer...      JayaHoIndia
# 99999   My 99-year-old great aunt got booked for her C...     jessicarobb_
# 100000  In boost for COVID-19 battle, Pfizer vaccine f...      Kelpwatcher
#
#         Like Count            Display Name Language
# 0                5                  USAGov       en
# 1                0                 Matthew       en
# 2                0        The Street Press       en
# 3                0  Demosthenies MAN / MAN       en
# 4               36           NxtLevelPromo       en
# ...            ...                     ...      ...
# 99996            0               Elizabeth       en
# 99997            1            Mindbodyslim      und
# 99998            1                Srikanth       en
# 99999           29                 jessica       en
# 100000           0        Kelpwatcher ⛵️🌹🔬       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-24').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df3 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df3.to_csv('Second Extract.csv')

# %%
tweets_df3
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-23 23:59:59+00:00  1364364414372093962
# 1      2021-02-23 23:59:49+00:00  1364364372441587718
# 2      2021-02-23 23:59:45+00:00  1364364354808856579
# 3      2021-02-23 23:59:43+00:00  1364364345426206722
# 4      2021-02-23 23:59:41+00:00  1364364338753110019
# ...                          ...                  ...
# 99996  2021-02-20 17:05:02+00:00  1363172823368404994
# 99997  2021-02-20 17:05:00+00:00  1363172815294193664
# 99998  2021-02-20 17:04:55+00:00  1363172793848848384
# 99999  2021-02-20 17:04:53+00:00  1363172785770680322
# 100000 2021-02-20 17:04:53+00:00  1363172785527349250
#
#                                                      Text         Username  \
# 0       Pasado na sa Senado ang Vaccine Program Bill! ...      SenGracePOE
# 1       @GovTimWalz Shame on you for claiming to care ...        Cooly9759
# 2       Covid-19 vaccine tracker\nGo Canada.  We’re no...          ZahnHug
# 3       golden by harry styles was playing while I got...  dxzzyoncaffeine
# 4       To be clear, I'm not saying take off your mask...   ChaseClark2260
# ...                                                   ...              ...
# 99996   Countries that have bought the most COVID vacc...    lovemoney_com
# 99997   Maharashtra to Approach Centre for Early Phase...        CNNnews18
# 99998   DHEC has updated the COVID-19 vaccine allocati...           scdhec
# 99999   @Doug_T79 @jeffstorobinsky @GovRonDeSantis Yea...  whattillersons1
# 100000  Getting ready for my COVID vaccine this week a...     hobbledchick
#
#         Like Count       Display Name Language
# 0               42          GRACE POE       tl
# 1                0              Cooly       en
# 2                0          justfedup       en
# 3                8               bb v       en
# 4                1        Chase Clark       en
# ...            ...                ...      ...
# 99996            0      lovemoney_com       en
# 99997           13             News18       en
# 99998            6             SCDHEC       en
# 99999            5  whattillersonsaid       en
# 100000           4      Hobbled Chick       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-20').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df4 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df4.to_csv('Third Extract.csv')

# %%
tweets_df4
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-19 23:59:58+00:00  1362914858409205761
# 1      2021-02-19 23:59:56+00:00  1362914848737140739
# 2      2021-02-19 23:59:55+00:00  1362914844165423104
# 3      2021-02-19 23:59:44+00:00  1362914799328366596
# 4      2021-02-19 23:59:43+00:00  1362914794848858115
# ...                          ...                  ...
# 99996  2021-02-17 04:25:47+00:00  1361894590232498180
# 99997  2021-02-17 04:25:41+00:00  1361894564336918529
# 99998  2021-02-17 04:25:40+00:00  1361894558653677568
# 99999  2021-02-17 04:25:37+00:00  1361894549241565189
# 100000 2021-02-17 04:25:37+00:00  1361894545684787202
#
#                                                      Text         Username  \
# 0       @KSL5TV If the @US_FDA doesn’t approve this em...        jewels_my
# 1       .@ABC's broadcast: LIVE: Our @ABC News team ha...  AmericaDialogue
# 2       We will continue to work towards making sure t...        rabrazzak
# 3       A Shot In the Arm - Infection prevention consi...       OSAPtweets
# 4       on the bright side 3 people in my family have ...       alliecsays
# ...                                                   ...              ...
# 99996   Delayed COVID-19 Vaccine Shipment Arrives, 698...           kw1979
# 99997   tonight a woman asked @POTUS about getting a c...  disneypinjunkie
# 99998   Yep Mike Liddell is back on the crack. He also...      john_ingr57
# 99999   Sidelined by vaccines? What's the latest resea...  globalfirstnews
# 100000  EU to fast track vaccines for COVID mutations ...  globalfirstnews
#
#         Like Count           Display Name Language
# 0                0                Jewel S       en
# 1                0  The American Dialogue       en
# 2                5             Rab Razzak       en
# 3                0               OSAP.org       en
# 4                1          usagi tsukino       en
# ...            ...                    ...      ...
# 99996            0                 kw1979       en
# 99997            0                   alan       en
# 99998            1         Electricblue57       en
# 99999            0       @globalfirstnews       en
# 100000           0       @globalfirstnews       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-17').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df5 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df5.to_csv('Fourth Extract.csv')

# %%
tweets_df5
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-16 23:59:59+00:00  1361827698272706566
# 1      2021-02-16 23:59:56+00:00  1361827686805475328
# 2      2021-02-16 23:59:56+00:00  1361827685341663232
# 3      2021-02-16 23:59:54+00:00  1361827679125663747
# 4      2021-02-16 23:59:54+00:00  1361827676428922890
# ...                          ...                  ...
# 99996  2021-02-13 11:44:10+00:00  1360555359757361156
# 99997  2021-02-13 11:44:08+00:00  1360555350542475267
# 99998  2021-02-13 11:44:05+00:00  1360555341130444803
# 99999  2021-02-13 11:44:05+00:00  1360555340257894406
# 100000 2021-02-13 11:44:05+00:00  1360555339582738434
#
#                                                      Text         Username  \
# 0       While they focused on bathroom bills, “show me...      BetoORourke
# 1       @pajhwok @AFP This is good for WHO to give Afg...  Estrell45533352
# 2       question: have you received a COVID vaccine ye...       avaryanne_
# 3       N.Y.C. Covid Vaccine Disparities Revealed in Z...         jt120651
# 4       @NIH @Pontifex @CardinalDolan @CardinalSean @C...      ArmorAuthor
# ...                                                   ...              ...
# 99996   Nearly a third of Americans are unsure about t...           MyNBC5
# 99997   Just saw a woman site “being from Tallaght” as...       DJLeapCard
# 99998   Nearly a third of Americans are unsure about t...         kcranews
# 99999   @deansfam4 @DrTomFrieden I Wouldn’t do it. The...        SimonBu12
# 100000  Nearly a third of Americans are unsure about t...        koat7news
#
#         Like Count                        Display Name Language
# 0            38973                       Beto O'Rourke       en
# 1                0                            Estrella       en
# 2                0                               ava♉︎       en
# 3                0                            jt120651       fr
# 4                0  Armor Of God Author Carl R Rushton       en
# ...            ...                                 ...      ...
# 99996            0                              MyNBC5       en
# 99997            0                        DJ Leap Card       en
# 99998            3                            kcranews       en
# 99999            0                            Simon Bu       en
# 100000           5                            KOAT.com       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-13').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df6 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df6.to_csv('Fifth Extract.csv')

# %%
tweets_df6
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-12 23:59:57+00:00  1360378137037709312
# 1      2021-02-12 23:59:53+00:00  1360378122328281089
# 2      2021-02-12 23:59:52+00:00  1360378117546770434
# 3      2021-02-12 23:59:51+00:00  1360378113704611841
# 4      2021-02-12 23:59:49+00:00  1360378104506699781
# ...                          ...                  ...
# 99996  2021-02-10 02:03:46+00:00  1359322134472974341
# 99997  2021-02-10 02:03:43+00:00  1359322123798368259
# 99998  2021-02-10 02:03:43+00:00  1359322123131641860
# 99999  2021-02-10 02:03:42+00:00  1359322118048124928
# 100000 2021-02-10 02:03:42+00:00  1359322117054021633
#
#                                                      Text        Username  \
# 0       125 hours on track for the next two weeks, so ...     InsideASCIF
# 1       Words i now detest....\nBubble, isolate, restr...       obmarch05
# 2       Swedish university wants to test-compare Covid...        LouSedin
# 3       California to open COVID-19 vaccine to people ...   KrisDisharoon
# 4       @tatereeves I just got email from Texas that d...   RobertroseJr2
# ...                                                   ...             ...
# 99996   65.28 lakh heathcare, frontline workers receiv...         pranpsp
# 99997   @brianlilley @JustinTrudeau rockefellers,WEF R...      MazurekRob
# 99998   Damn... Our family friend got CoVid. He got th...      arnoblalam
# 99999   “COVID testing” is the ultimate racket.  Even ...         FlyrUsr
# 100000  @ImagesMD @sallypipes @dcexaminer Good questio...  butchgarciadmd
#
#         Like Count                              Display Name Language
# 0                1             He's Still Your President 😆😆😆       en
# 1                2                                    Tiktok       en
# 2                0                          loumubarak@gmail       en
# 3                0                                Kristopher       en
# 4                0                           Robert rose Jr.       en
# ...            ...                                       ...      ...
# 99996            0                         Pranav Pendharkar       en
# 99997            0                               Rob Mazurek       en
# 99998            0  Arnob 'missile defense is a scam' Alam 🌐       en
# 99999            8                                  Usr Flyr       en
# 100000           0                         Butch Garcia, DMD       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-10').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df7 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df7.to_csv('Sixth Extract.csv')

# %%
tweets_df7
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-09 23:59:51+00:00  1359290949118091268
# 1      2021-02-09 23:59:48+00:00  1359290937315381248
# 2      2021-02-09 23:59:46+00:00  1359290928540827648
# 3      2021-02-09 23:59:42+00:00  1359290912510070784
# 4      2021-02-09 23:59:42+00:00  1359290910455037956
# ...                          ...                  ...
# 99996  2021-02-06 17:12:40+00:00  1358101316854296577
# 99997  2021-02-06 17:12:39+00:00  1358101309250011141
# 99998  2021-02-06 17:12:38+00:00  1358101306666217472
# 99999  2021-02-06 17:12:36+00:00  1358101299372253189
# 100000 2021-02-06 17:12:35+00:00  1358101294892933121
#
#                                                      Text       Username  \
# 0       J&amp;J's single-dose Covid vaccine is being h...           CNBC
# 1       [WATCH] She took the Covid 19 Moderna Vax and ...  TorontoWriter
# 2       UPDATE ON STOLEN COVID 19 DOSES | 🧵| We have a...  RosalesReport
# 3       Oklahoma postponed megapods of COVID-19 vaccin...   ExBulletinUk
# 4       How chronic underfunding fueled Georgia’s Covi...       storbush
# ...                                                   ...            ...
# 99996   @RobbieScrivene1 @dover_is @Mark_Hartshorne @B...       Jo_el_le
# 99997   If the elderly, people with autoimmune disease...       Beth_E_K
# 99998   If your loved one is hesitant to get the Covid...    Cmusiclover
# 99999   If your loved one is hesitant to get the Covid...         drlups
# 100000  As Employers Consider Mandatory COVID-19 Vacci...    patentbuddy
#
#         Like Count              Display Name Language
# 0               16                      CNBC       en
# 1                1             torontowriter       en
# 2                0            Isabel Rosales       en
# 3                0                ExBulletin       en
# 4                0             susan torbush       en
# ...            ...                       ...      ...
# 99996            1         Joelle Ballestraz       en
# 99997          227                     BethK       en
# 99998            0  Carol 🌊✊🏻🇺🇸 #ResistTrump       en
# 99999            0            Lupita Almonte       en
# 100000           0               PatentBuddy       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-06').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df8 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df8.to_csv('Seventh Extract')

# %%
tweets_df8
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-05 23:59:55+00:00  1357841415347273729
# 1      2021-02-05 23:59:51+00:00  1357841398645547010
# 2      2021-02-05 23:59:50+00:00  1357841393973157894
# 3      2021-02-05 23:59:37+00:00  1357841340571213827
# 4      2021-02-05 23:59:35+00:00  1357841332543365121
# ...                          ...                  ...
# 99996  2021-02-03 12:45:08+00:00  1356946822565158913
# 99997  2021-02-03 12:45:07+00:00  1356946822271500288
# 99998  2021-02-03 12:45:06+00:00  1356946816911237120
# 99999  2021-02-03 12:45:04+00:00  1356946807947984897
# 100000 2021-02-03 12:45:03+00:00  1356946805032947713
#
#                                                      Text      Username  \
# 0       The 3 links mentioned this hour on @catholicco...   FrMatthewLC
# 1       THIS SUNDAY: Days before the Senate impeachmen...  MeetThePress
# 2       At 8 a.m. on Feb. 8, we'll launch a #COVID19 V...   mynorthoaks
# 3       @Albazalaza La débilité de cette phrase... Com...       Pagayix
# 4       @am_draper @AllanGPaterson My reaction was aki...    panicmedic
# ...                                                   ...           ...
# 99996   Within two hours, all available timeslots for ...     FOX13News
# 99997   As COVID-19 vaccines come on the market, there...          FOX9
# 99998   The Oxford-AstraZeneca Covid-19 vaccine may re...          cnni
# 99999   📢 Funding Opportunity - Call for Proposals 📢\n...         FNHMA
# 100000  Black People Will Accept Covid-19 Vaccines But...      SantitaJ
#
#         Like Count                                   Display Name Language
# 0               23                      Fr Matthew Schneider LC 🙏       en
# 1               16                                 Meet the Press       en
# 2                1                       North Oaks Health System       en
# 3                0                                      PAGAYISMO       fr
# 4                1                            Mark Jacobs 🇪🇺 🤝 🇬🇧       en
# ...            ...                                            ...      ...
# 99996            1                               FOX 13 Tampa Bay       en
# 99997            2                                          FOX 9       en
# 99998          205                              CNN International       en
# 99999            2  The First Nations Health Managers Association       en
# 100000           0                                Santita Jackson       en
#
# [100001 rows x 7 columns]

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid vaccine until:2021-02-03').get_items()):
    if i>100000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df9 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df9.to_csv('Eighth Extract.csv')

# %%
tweets_df9
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-02-02 23:59:58+00:00  1356754262525571074
# 1      2021-02-02 23:59:57+00:00  1356754258096455687
# 2      2021-02-02 23:59:56+00:00  1356754256531845122
# 3      2021-02-02 23:59:54+00:00  1356754248046759936
# 4      2021-02-02 23:59:53+00:00  1356754241247989764
# ...                          ...                  ...
# 99996  2021-01-31 11:28:49+00:00  1355840454584131587
# 99997  2021-01-31 11:28:47+00:00  1355840445910233088
# 99998  2021-01-31 11:28:46+00:00  1355840443473424384
# 99999  2021-01-31 11:28:38+00:00  1355840410866704384
# 100000 2021-01-31 11:28:34+00:00  1355840391644381184
#
#                                                      Text         Username  \
# 0       @TheTorontoSun Because it's Calgary and not Mo...      CRC57325971
# 1       I do have an issue with all the news stories a...           wgkcss
# 2       A survey spearheaded by UST researchers shows ...   cnnphilippines
# 3       "Trudeau announces deal to manufacture COVID-1...    RemnantVessal
# 4       The PlayStation 5 &amp; covid vaccine roll out...            ceb3_
# ...                                                   ...              ...
# 99996   The @LGBTfdn &amp; I are carrying out a survey...  CarlAustinBehan
# 99997   UK restricts COVID medicine exports amid Astra...        EHijacked
# 99998   @Asad_Umar Pakistan battles tsunami of Covid-1...  AamirGhazanfarS
# 99999   // waking up the COVID vaccine inside me by go...       LEGATARlUS
# 100000  @sturdyAlex @PeterBarker23 "Much ado about not...      Save_EU_org
#
#         Like Count                                Display Name Language
# 0                1                                         CRC       en
# 1                1                William 🎩 Gentleman Overlord       en
# 2               19                             CNN Philippines       en
# 3                0                             Endtime Remnant       en
# 4               10                                     charity       en
# ...            ...                                         ...      ...
# 99996            6                  Carl Austin-Behan OBE DL 🐝       en
# 99997            1  HijackedEUrophile - #FBPE #FBPPR #FBPA - 💙       en
# 99998            5                             Aamir Ghazanfar       en
# 99999            5                           ♔ 𝘫𝘶𝘭𝘪𝘶𝘴 𝘥𝘦 𝘷𝘰𝘨𝘦𝘭       en
# 100000           0                                     Save EU       en
#
# [100001 rows x 7 columns]

# %%
Tweets_Feb = pd.concat([tweets_df2,tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7,tweets_df8,tweets_df9])

# %%
Tweets_Feb.shape
# Out:
# (800008, 7)

# %%
Tweets_Feb.to_csv('Tweets_Feb.csv')
